# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
import math

# %% [markdown]
# # Введение в аналитическую геометрию

# %% [markdown]
# ## Векторы на плоскости и в пространстве
# -упорядоченная последоавтельность нескольких действительных чисел

# %% [markdown]
# Длина векторов

# %%
# Вариант 1
x = 10
y = 5
z = 2

X_len = math.sqrt(x**2+y**2+z**2)
X_len
# Out:
# 11.357816691600547

# %%
# Вариант 2
X = np.array([10,5,2])

X_len = math.sqrt((X[0])**2 + (X[1])**2 + (X[2])**2)
X_len
# Out:
# 11.357816691600547

# %% [markdown]
# ## Прямая на плоскости

# %% [markdown]
# Уравнение прямой на плоскости
# ```
# y = k*x + b
# Ax + By + с = 0
# ```

# %%
x = np.linspace(-5,5,21)
y = 2*x
y2 = 2*x+1

plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel('x')
plt.ylabel('y')
plt.grid();

# %%
rcParams['figure.figsize'] = 5, 5

x = np.linspace(-2, 5, 21)
y = 3*x+1
y2 = (-1/3)*x+1
plt.plot(x,y)
plt.plot(x,y2)
plt.xlabel("x")
plt.ylabel("y")
plt.grid();

# %%
x = []
y1 = []
y2 = []
p = 5
for i in range(1000):
    x_ = i/1000
    x.append(x_)
    y1.append(math.sqrt(2*p*x_))
    y2.append(-math.sqrt(2*p*x_))    
plt.plot(x,y1)
plt.plot(x,y2)
plt.xlabel("x")
plt.ylabel("y");

# %% [markdown]
# ## Графики линий и поверхностей в протранстве

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = figure()  # отрисовка 3D пространства
ax = Axes3D(fig)  # отрисовка 3D пространства
X = np.arange(-5, 5, 0.5)
Y = np.arange(-5, 5, 0.5)
X,Y = np.meshgrid(X,Y)
Z = 2*X + 5*Y
ax.plot_wireframe(X,Y,Z)  # график плоскости
ax.scatter(0,0,0,'z',50,'red');  # график точки

# %%
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 2)
Y = np.arange(-50, 50, 20)
# print(X)
X, Y = np.meshgrid(X, Y)
# print(Y)
# print(X[1,1])
Z = np.sqrt(X**2 + Y**2)
Z2 = 2*X + 3*Y
ax.plot_surface(X, Y, Z)
ax.plot_surface(X, Y, Z2)
ax.scatter(0, 0, 0,'z',50,'red');

# %%
# Построение прямых линий
fig = figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 2)
Y = np.arange(-5, 5, 2)

Z = 2*X + 3*Y
ax.plot(X, Y, Z, 'red')
ax.plot(X, Y, 2*Z)
ax.scatter(0, 0, 0,'z',50,'red');
